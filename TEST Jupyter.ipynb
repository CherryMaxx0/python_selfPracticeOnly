# %%
name_list = {}
name_list.update({'random':20,'multi':50,'listss':[1,2,3],'hell':{'core':2,'cover':[5,4]}})
print(name_list)
value = name_list.get('hell','?').get('cover','?')[1]
print(value)
# Out:
# {'random': 20, 'multi': 50, 'listss': [1, 2, 3], 'hell': {'core': 2, 'cover': [5, 4]}}
# 4
